# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

#reading cars dataset
df = pd.read_csv("car_data.csv")

# %%
#printing first 30 rows
df.head(30)
# Out:
#          Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0            ritz  2014           3.35           5.59       27000    Petrol
# 1             sx4  2013           4.75           9.54       43000    Diesel
# 2            ciaz  2017           7.25           9.85        6900    Petrol
# 3         wagon r  2011           2.85           4.15        5200    Petrol
# 4           swift  2014           4.60           6.87       42450    Diesel
# 5   vitara brezza  2018           9.25           9.83        2071    Diesel
# 6            ciaz  2015           6.75           8.12       18796    Petrol
# 7         s cross  2015           6.50           8.61       33429    Diesel
# 8            ciaz  2016           8.75           8.89       20273    Diesel
# 9            ciaz  2015           7.45           8.92       42367    Diesel
# 10       alto 800  2017           2.85           3.60        2135    Petrol
# ...

# %%
df.shape
# Out:
# (301, 9)

# %%
#display details about columns and rows
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
df.describe()#statistical data
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
#check if our data contains any missing piece
data = df.drop_duplicates(subset="Car_Name")
data
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 215    verna  2012           4.50           9.40       36100    Petrol
# 251     city  2013           5.00           9.90       56701    Petrol
# 252     brio  2015           5.40           6.82       31427    Petrol
# 259    amaze  2014           3.90           7.00       36054    Petrol
# 263     jazz  2016           6.60           7.70       16002    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
#check if dataset is balanced or not 
df.value_counts("Car_Name")
# Out:
# Car_Name
# city                      26
# corolla altis             16
# verna                     14
# fortuner                  11
# brio                      10
#                           ..
# Hero Passion X pro         1
# Hero Hunk                  1
# camry                      1
# Hero Honda Passion Pro     1
# 800                        1
# Length: 98, dtype: int64

# %%
df.plot()
plt.show()

# %%
df.plot(kind='scatter',x='Selling_Price',y='Present_Price',color='r')
plt.show()

# %%
ax=plt.subplots(1,1,figsize=(10,8))
df['Fuel_Type'].value_counts().plot.pie(explode=[0.1,0.1,0.1],autopct='%1.1f%%',shadow=False)
plt.title("Fuel_Type")
plt.show()

# %%
arr=np.array(df['Selling_Price'])
print(arr)
print(arr.ndim)
print(arr.shape)
print(arr.size)
print(arr.strides)
print(type(arr))
print(arr.data)
# Out:
# [ 3.35  4.75  7.25  2.85  4.6   9.25  6.75  6.5   8.75  7.45  2.85  6.85
#   7.5   6.1   2.25  7.75  7.25  7.75  3.25  2.65  2.85  4.9   4.4   2.5
#   2.9   3.    4.15  6.    1.95  7.45  3.1   2.35  4.95  6.    5.5   2.95
#   4.65  0.35  3.    2.25  5.85  2.55  1.95  5.5   1.25  7.5   2.65  1.05
#   5.8   7.75 14.9  23.   18.   16.    2.75  3.6   4.5   4.75  4.1  19.99
#   6.95  4.5  18.75 23.5  33.    4.75 19.75  9.25  4.35 14.25  3.95  4.5
#   7.45  2.65  4.9   3.95  5.5   1.5   5.25 14.5  14.73  4.75 23.   12.5
#   3.49  2.5  35.    5.9   3.45  4.75  3.8  11.25  3.51 23.    4.    5.85
#  20.75 17.    7.05  9.65  1.75  1.7   1.65  1.45  1.35  1.35  1.35  1.25
#   1.2   1.2   1.2   1.15  1.15  1.15  1.15  1.11  1.1   1.1   1.1   1.05
#   1.05  1.05  1.05  1.    0.95  0.9   0.9   0.75  0.8   0.78  0.75  0.75
#   0.75  0.72  0.65  0.65  0.65  0.65  0.6   0.6   0.6   0.6   0.6   0.6
#   0.6   0.6   0.55  0.55  0.52  0.51  0.5   0.5   0.5   0.5   0.5   0.48
# ...

# %%
arr1=np.array(df['Present_Price'])
print(arr1)
print(arr1.ndim)
print(arr1.shape)
print(arr1.size)
print(arr1.strides)
print(type(arr1))
print(arr1.data)
# Out:
# [ 5.59   9.54   9.85   4.15   6.87   9.83   8.12   8.61   8.89   8.92
#   3.6   10.38   9.94   7.71   7.21  10.79  10.79  10.79   5.09   7.98
#   3.95   5.71   8.01   3.46   4.41   4.99   5.87   6.49   3.95  10.38
#   5.98   4.89   7.49   9.95   8.06   7.74   7.2    2.28   3.76   7.98
#   7.87   3.98   7.15   8.06   2.69  12.04   4.89   4.15   7.71   9.29
#  30.61  30.61  19.77  30.61  10.21  15.04   7.27  18.54   6.8   35.96
#  18.61   7.7   35.96  35.96  36.23   6.95  23.15  20.45  13.74  20.91
#   6.76  12.48  18.61   5.71   8.93   6.8   14.68  12.35  22.83  30.61
#  14.89   7.85  25.39  13.46  13.46  23.73  92.6   13.74   6.05   6.76
#  18.61  16.09  13.7   30.61  22.78  18.61  25.39  18.64  18.61  20.45
#   1.9    1.82   1.78   1.6    1.47   2.37   3.45   1.5    1.5    1.47
#   1.78   1.5    2.4    1.4    1.47   1.47   1.47   1.9    1.47   1.9
#   1.26   1.5    1.17   1.47   1.75   1.75   0.95   0.8    0.87   0.84
# ...

# %%
#mathematical functions for selling price
print("For Selling price")
print("Mean",np.mean(arr))

print("Median",np.median(arr))

print("sum",np.sum(arr))

print("Standard Deviation",np.std(arr))
# Out:
# For Selling price
# Mean 4.661295681063123
# Median 3.6
# sum 1403.0500000000002
# Standard Deviation 5.074361323307891
